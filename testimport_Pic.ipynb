# %% [markdown]
# <a href="https://colab.research.google.com/github/Kggzzz/KKU_data_mining/blob/master/testimport_Pic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')

path = '/content/drive/My Drive/shadeimg/รูปฟัน07'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install azure-storage-blob==2.1.0

# %%
from azure.storage.blob import BlockBlobService
import os

# %%
blob_service_client = BlockBlobService(account_name='dent01', account_key='CuShY0B4TZJ84TjzPpaHxyrHOpO73aGXeCpdVq7x26OjIlQ1HOz+3DVc9pDEj9BdcEL8odFuTRF0mOAE+aCgiw==')

# %%
img_8863 = '29FAFD3A-C2C2-4B40-B833-04F593ABFD8.png'

# %%
full_path_to_file2 = os.path.join(img_8863)
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)
# Out:
# Client-Request-ID=08f3f2f6-e259-11eb-baa3-0242ac1c0002 Retry policy did not allow for a retry: Server-Timestamp=Sun, 11 Jul 2021 15:02:39 GMT, Server-Request-ID=c000a6f8-201e-0029-7b65-76ef77000000, HTTP status code=404, Exception=The specified blob does not exist. ErrorCode: BlobNotFound<?xml version="1.0" encoding="utf-8"?><Error><Code>BlobNotFound</Code><Message>The specified blob does not exist.RequestId:c000a6f8-201e-0029-7b65-76ef77000000Time:2021-07-11T15:02:39.8055580Z</Message></Error>.
# ---------------------------------------------------------------------------
# AzureMissingResourceHttpError             Traceback (most recent call last)
# <ipython-input-35-157811ef8bba> in <module>()
#       1 full_path_to_file2 = os.path.join(img_8863)
# ----> 2 blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)
#
# ...

# %%
import cv2 #ใช้เกี่ยวกับรูปภาพ

# %%
img = cv2.imread(os.path.join(path,'IMG_8828.JPG'))

# %%
from matplotlib import pyplot as plt

# %%
RGB_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
